# %%
# nombre original archivo: G entrenamiento-Bisenet-2025-automine1d-advtrain guardando bothpth2 DaccestoMask

# %%
## 进入MMSegmentation主目录
import os
os.chdir('/mmsegmentation/')

# %% [markdown]
# os.getcwd()

# %%
# !PYTHONPATH=. python tools/train.py zmax_configs/03_train_adaptive_scheduler_02pretrain.py
# Out:
# /home/maximilianovelez/miniconda3/envs/open-mmlab-respaldo2/lib/python3.8/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /bin/sh: 1: x86_64-conda_cos6-linux-gnu-gcc: not found
# 04/26 23:44:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1123959112
#     GPU 0,1: NVIDIA A100 80GB PCIe
#     CUDA_HOME: /home/maximilianovelez/miniconda3/envs/open-mmlab-respaldo2
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: n/a
#     PyTorch: 1.13.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     seed: 1123959112
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/26 23:44:22 - mmengine - INFO - Config:
# DATA_ROOT_TRAIN = '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/0_secuencias_ann/1a_secuencia'
# DATA_ROOT_VAL = '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/0_secuencias_ann/1a_secuencia_val_mixed'
# TRAIN_CLS_FILE = 'cls_labels_train_k30_sparsegt.txt'
# TRAIN_PAIR_FILE = 'train_pairs_k30_devtargets.txt'
# VAL_CLS_FILE = 'cls_labels_val_mixed.txt'
# VAL_PAIR_FILE = 'val_pairs_mixed_devtargets.txt'
# custom_hooks = []
# custom_imports = dict(
#     allow_failed_imports=False,
#     imports=[
#         'mmseg.structures.dual_task_seg_data_sample',
#         'mmseg.models.cls_heads.simple_cls_head',
#         'mmseg.models.backbones.bisenetv1',
#         'mmseg.models.backbones.resnet',
#         'mmseg.datasets.scheduler_video_pair_dual_task_dataset',
#         'mmseg.datasets.transforms.pack_scheduler_video_pair_inputs',
#         'mmseg.datasets.transforms.load_video_pair',
#         'mmseg.datasets.transforms.resize_video_pair',
#         'mmseg.datasets.transforms.random_flip_video_pair',
#         'mmseg.datasets.transforms.pair_random_clahe_video_pair',
#         'mmseg.datasets.transforms.pair_photometric_distortion_video_pair',
#         'mmseg.datasets.transforms.map_cls_after_flip',
#         'mmseg.models.data_preprocessors.pair_seg_data_preprocessor',
#         'mmseg.models.video_modules.adaptive_feature_propagation',
#         'mmseg.models.video_modules.adaptive_keyframe_selector',
#         'mmseg.models.segmentors.bisenet_adaptive_video_segmentor',
#     ])
# dataset_type = 'SchedulerVideoPairDualTaskDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=200,
#         max_keep_ckpts=3,
#         rule=[
#             'greater',
#             'greater',
#         ],
#         save_best=[
#             'seg/mIoU',
#             'cls/acc_cls_top1',
#         ],
#         save_last=True,
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(cudnn_benchmark=False)
# launcher = 'none'
# load_from = '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/mmsegmentation/work_dirs/bisenet_adaptive_propagation_seqaug_pretrain/best_cls_acc_cls_top1_iter_2200.pth'
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         backbone_cfg=dict(
#             depth=50,
#             dilations=(
#                 1,
#                 1,
#                 1,
#                 1,
#             ),
#             in_channels=3,
#             init_cfg=dict(
#                 checkpoint='open-mmlab://resnet50_v1c', type='Pretrained'),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             norm_eval=False,
#             num_stages=4,
#             out_indices=(
#                 0,
#                 1,
#                 2,
#                 3,
#             ),
#             strides=(
#                 1,
#                 2,
#                 2,
#                 2,
#             ),
#             style='pytorch',
#             type='ResNetV1c'),
#         context_channels=(
#             512,
#             1024,
#             2048,
#         ),
#         in_channels=3,
#         init_cfg=None,
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         out_channels=1024,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         spatial_channels=(
#             256,
#             256,
#             256,
#             512,
#         ),
#         type='BiSeNetV1'),
#     cls_head=dict(
#         in_channels=1024,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=3,
#         type='SimpleClsHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='PairSegDataPreProcessor'),
#     decode_head=dict(
#         channels=1024,
#         in_channels=1024,
#         in_index=0,
#         loss_decode=dict(
#             loss_weight=0.5, type='CrossEntropyLoss', use_sigmoid=False),
#         num_classes=2,
#         type='FCNHead'),
#     feature_propagation=dict(
#         context_channels=512,
#         hidden_channels=128,
#         kernel_size=3,
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         refine=True,
#         spatial_channels=512,
#         type='AdaptiveFeaturePropagation'),
#     freeze_base=True,
#     keyframe_selector=dict(
#         hidden_channels=128,
#         in_channels=512,
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         type='AdaptiveKeyFrameSelector'),
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     train_mode='scheduler',
#     type='BiSeNetAdaptiveVideoSegmentor')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             backbone=dict(decay_mult=0.0, lr_mult=0.0),
#             cls_head=dict(decay_mult=0.0, lr_mult=0.0),
#             decode_head=dict(decay_mult=0.0, lr_mult=0.0),
#             feature_propagation=dict(decay_mult=0.0, lr_mult=0.0),
#             keyframe_selector=dict(decay_mult=1.0, lr_mult=1.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(by_epoch=False, eta_min=1e-05, power=0.9, type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         cls_labels_file='cls_labels_val_mixed.txt',
#         data_prefix=dict(img_path='img', seg_map_path='ann'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/0_secuencias_ann/1a_secuencia_val_mixed',
#         pair_file='val_pairs_mixed_devtargets.txt',
#         pipeline=[
#             dict(type='LoadVideoPairFromFile'),
#             dict(scale=(
#                 512,
#                 512,
#             ), type='ResizeVideoPair'),
#             dict(type='PackSchedulerVideoPairInputs'),
#         ],
#         test_mode=True,
#         type='SchedulerVideoPairDualTaskDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(iou_metrics=[
#         'mIoU',
#     ], prefix='seg', type='IoUMetric'),
#     dict(prefix='cls', topk=(1, ), type='ClsAccuracy'),
# ]
# train_cfg = dict(max_iters=20000, type='IterBasedTrainLoop', val_interval=200)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         cls_labels_file='cls_labels_train_k30_sparsegt.txt',
#         data_prefix=dict(img_path='img', seg_map_path='ann'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/0_secuencias_ann/1a_secuencia',
#         pair_file='train_pairs_k30_devtargets.txt',
#         pipeline=[
#             dict(type='LoadVideoPairFromFile'),
#             dict(scale=(
#                 512,
#                 512,
#             ), type='ResizeVideoPair'),
#             dict(direction='horizontal', prob=0.5, type='RandomFlipVideoPair'),
#             dict(
#                 field_name='gt_label',
#                 map_if_flipped=dict({
#                     0: 2,
#                     1: 1,
#                     2: 0
#                 }),
#                 str_map_if_flipped=dict(
#                     LEFT='RIGHT',
#                     RIGHT='LEFT',
#                     STRAIGHT='STRAIGHT',
#                     derecha='izquierda',
#                     izquierda='derecha',
#                     recta='recta'),
#                 type='MapClsAfterFlip'),
#             dict(
#                 clip_limit=2.0,
#                 prob=0.3,
#                 tile_grid_size=(
#                     7,
#                     7,
#                 ),
#                 type='PairRandomCLAHEVideoPair'),
#             dict(type='PairPhotoMetricDistortionVideoPair'),
#             dict(type='PackSchedulerVideoPairInputs'),
#         ],
#         type='SchedulerVideoPairDualTaskDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadVideoPairFromFile'),
#     dict(scale=(
#         512,
#         512,
#     ), type='ResizeVideoPair'),
#     dict(direction='horizontal', prob=0.5, type='RandomFlipVideoPair'),
#     dict(
#         field_name='gt_label',
#         map_if_flipped=dict({
#             0: 2,
#             1: 1,
#             2: 0
#         }),
#         str_map_if_flipped=dict(
#             LEFT='RIGHT',
#             RIGHT='LEFT',
#             STRAIGHT='STRAIGHT',
#             derecha='izquierda',
#             izquierda='derecha',
#             recta='recta'),
#         type='MapClsAfterFlip'),
#     dict(
#         clip_limit=2.0,
#         prob=0.3,
#         tile_grid_size=(
#             7,
#             7,
#         ),
#         type='PairRandomCLAHEVideoPair'),
#     dict(type='PairPhotoMetricDistortionVideoPair'),
#     dict(type='PackSchedulerVideoPairInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         cls_labels_file='cls_labels_val_mixed.txt',
#         data_prefix=dict(img_path='img', seg_map_path='ann'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/0_secuencias_ann/1a_secuencia_val_mixed',
#         pair_file='val_pairs_mixed_devtargets.txt',
#         pipeline=[
#             dict(type='LoadVideoPairFromFile'),
#             dict(scale=(
#                 512,
#                 512,
#             ), type='ResizeVideoPair'),
#             dict(type='PackSchedulerVideoPairInputs'),
#         ],
#         test_mode=True,
#         type='SchedulerVideoPairDualTaskDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = [
#     dict(iou_metrics=[
#         'mIoU',
#     ], prefix='seg', type='IoUMetric'),
#     dict(prefix='cls', topk=(1, ), type='ClsAccuracy'),
# ]
# val_pipeline = [
#     dict(type='LoadVideoPairFromFile'),
#     dict(scale=(
#         512,
#         512,
#     ), type='ResizeVideoPair'),
#     dict(type='PackSchedulerVideoPairInputs'),
# ]
# work_dir = './work_dirs/bisenet_adaptive_scheduler_from_pretrain02'
#
# /home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 04/26 23:44:26 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# /home/maximilianovelez/00_openmmlab_respaldo/probando_low_latency/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '
# 04/26 23:44:26 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.0.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.4.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.4.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.6.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.7.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.stem.7.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.downsample.0.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.downsample.1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.0.downsample.1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.1.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer1.2.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.downsample.0.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.downsample.1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.0.downsample.1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.1.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.2.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer2.3.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.downsample.0.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.downsample.1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.0.downsample.1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.1.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.2.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.3.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.4.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer3.5.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.downsample.0.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.downsample.1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.0.downsample.1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.1.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.conv1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn1.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn1.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.conv2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn2.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn2.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.conv3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn3.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.backbone.layer4.2.bn3.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.conv_layer.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.conv_layer.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.conv_layer.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.atten_conv_layer.1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.atten_conv_layer.1.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm16.atten_conv_layer.1.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.conv_layer.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.conv_layer.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.conv_layer.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.atten_conv_layer.1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.atten_conv_layer.1.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.arm32.atten_conv_layer.1.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head32.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head32.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head32.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head16.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head16.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.conv_head16.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.gap_conv.1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.gap_conv.1.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.context_path.gap_conv.1.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer1.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer1.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer2.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer2.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer2.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer3.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer3.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer3.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer4.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer4.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.spatial_path.layer4.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv1.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv1.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv_atten.0.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv_atten.0.bn.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - backbone.ffm.conv_atten.0.bn.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.conv_seg.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.conv_seg.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.convs.0.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.convs.0.conv.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.convs.1.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.convs.1.conv.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.conv_cat.conv.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - decode_head.conv_cat.conv.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - cls_head.fc.weight is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - WARNING - cls_head.fc.bias is skipped since its requires_grad=False
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.conv.weight:lr=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.conv.weight:weight_decay=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.conv.weight:lr_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.conv.weight:decay_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.weight:lr=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.weight:weight_decay=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.weight:lr_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.weight:decay_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.bias:lr=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.bias:weight_decay=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.bias:lr_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_key.bn.bias:decay_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.conv.weight:lr=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.conv.weight:weight_decay=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.conv.weight:lr_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.conv.weight:decay_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.bn.weight:lr=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.bn.weight:weight_decay=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.bn.weight:lr_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.bn.weight:decay_mult=0.0
# 04/26 23:44:28 - mmengine - INFO - paramwise_options -- feature_propagation.kernel_predictor.reduce_cur.bn.bias:lr=0.0
# ...
# 04/27 01:06:24 - mmengine - INFO - Epoch(train) [1][18400/20]  base_lr: 1.1196e-04 lr: 8.9701e-06  eta: 0:06:09  time: 0.1028  data_time: 0.0748  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0012  scheduler/dev_pred_mean: 0.0173  scheduler/dev_target_mean: 0.0173
# 04/27 01:06:24 - mmengine - INFO - Saving checkpoint at 18400 iterations
# 04/27 01:06:29 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0561  data_time: 0.0311  memory: 587
# 04/27 01:06:31 - mmengine - INFO - per class results:
# 04/27 01:06:31 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.76 | 94.25 |
# |    road    | 87.98 | 98.86 |
# +------------+-------+-------+
# 04/27 01:06:31 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7100  seg/mIoU: 90.8700  seg/mAcc: 96.5600  cls/acc_cls_top1: 67.8571  data_time: 0.0330  time: 0.0579
# 04/27 01:06:44 - mmengine - INFO - Epoch(train) [1][18450/20]  base_lr: 1.0909e-04 lr: 8.9991e-06  eta: 0:05:58  time: 0.3549  data_time: 0.3266  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0020  scheduler/dev_pred_mean: 0.0118  scheduler/dev_target_mean: 0.0098
# 04/27 01:06:54 - mmengine - INFO - Epoch(train) [1][18500/20]  base_lr: 1.0621e-04 lr: 9.0282e-06  eta: 0:05:46  time: 0.1064  data_time: 0.0782  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0013  scheduler/dev_pred_mean: 0.0216  scheduler/dev_target_mean: 0.0208
# 04/27 01:07:07 - mmengine - INFO - Epoch(train) [1][18550/20]  base_lr: 1.0332e-04 lr: 9.0574e-06  eta: 0:05:34  time: 0.3524  data_time: 0.3242  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0007  scheduler/dev_pred_mean: 0.0163  scheduler/dev_target_mean: 0.0156
# 04/27 01:07:17 - mmengine - INFO - Epoch(train) [1][18600/20]  base_lr: 1.0042e-04 lr: 9.0867e-06  eta: 0:05:23  time: 0.1056  data_time: 0.0775  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0009  scheduler/dev_pred_mean: 0.0174  scheduler/dev_target_mean: 0.0173
# 04/27 01:07:17 - mmengine - INFO - Saving checkpoint at 18600 iterations
# 04/27 01:07:22 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0566  data_time: 0.0323  memory: 587
# 04/27 01:07:24 - mmengine - INFO - per class results:
# 04/27 01:07:24 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.66 | 94.15 |
# |    road    | 87.82 | 98.87 |
# +------------+-------+-------+
# 04/27 01:07:24 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.6500  seg/mIoU: 90.7400  seg/mAcc: 96.5100  cls/acc_cls_top1: 67.8571  data_time: 0.0335  time: 0.0580
# 04/27 01:07:37 - mmengine - INFO - Epoch(train) [1][18650/20]  base_lr: 9.7504e-05 lr: 9.1161e-06  eta: 0:05:11  time: 0.3537  data_time: 0.3248  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0009  scheduler/dev_pred_mean: 0.0178  scheduler/dev_target_mean: 0.0177
# 04/27 01:07:47 - mmengine - INFO - Epoch(train) [1][18700/20]  base_lr: 9.4582e-05 lr: 9.1456e-06  eta: 0:05:00  time: 0.1036  data_time: 0.0753  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0007  scheduler/dev_pred_mean: 0.0158  scheduler/dev_target_mean: 0.0160
# 04/27 01:08:00 - mmengine - INFO - Epoch(train) [1][18750/20]  base_lr: 9.1648e-05 lr: 9.1753e-06  eta: 0:04:48  time: 0.3546  data_time: 0.3264  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0023  scheduler/dev_pred_mean: 0.0129  scheduler/dev_target_mean: 0.0106
# 04/27 01:08:10 - mmengine - INFO - Epoch(train) [1][18800/20]  base_lr: 8.8703e-05 lr: 9.2050e-06  eta: 0:04:37  time: 0.1042  data_time: 0.0760  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0013  scheduler/dev_pred_mean: 0.0133  scheduler/dev_target_mean: 0.0122
# 04/27 01:08:10 - mmengine - INFO - Saving checkpoint at 18800 iterations
# 04/27 01:08:15 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0560  data_time: 0.0317  memory: 587
# 04/27 01:08:17 - mmengine - INFO - per class results:
# 04/27 01:08:17 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.69 | 94.18 |
# |    road    | 87.87 | 98.87 |
# +------------+-------+-------+
# 04/27 01:08:17 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.6700  seg/mIoU: 90.7800  seg/mAcc: 96.5300  cls/acc_cls_top1: 66.6667  data_time: 0.0327  time: 0.0574
# 04/27 01:08:30 - mmengine - INFO - Epoch(train) [1][18850/20]  base_lr: 8.5745e-05 lr: 9.2349e-06  eta: 0:04:25  time: 0.3543  data_time: 0.3259  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0017  scheduler/dev_pred_mean: 0.0213  scheduler/dev_target_mean: 0.0230
# 04/27 01:08:40 - mmengine - INFO - Epoch(train) [1][18900/20]  base_lr: 8.2775e-05 lr: 9.2649e-06  eta: 0:04:13  time: 0.1059  data_time: 0.0775  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0012  scheduler/dev_pred_mean: 0.0149  scheduler/dev_target_mean: 0.0137
# 04/27 01:08:53 - mmengine - INFO - Epoch(train) [1][18950/20]  base_lr: 7.9791e-05 lr: 9.2950e-06  eta: 0:04:02  time: 0.3592  data_time: 0.3307  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0010  scheduler/dev_pred_mean: 0.0131  scheduler/dev_target_mean: 0.0130
# 04/27 01:09:03 - mmengine - INFO - Exp name: 03_train_adaptive_scheduler_02pretrain_20260426_234420
# 04/27 01:09:03 - mmengine - INFO - Epoch(train) [1][19000/20]  base_lr: 7.6793e-05 lr: 9.3253e-06  eta: 0:03:50  time: 0.1056  data_time: 0.0769  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0016  scheduler/dev_pred_mean: 0.0187  scheduler/dev_target_mean: 0.0183
# 04/27 01:09:03 - mmengine - INFO - Saving checkpoint at 19000 iterations
# 04/27 01:09:08 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0553  data_time: 0.0295  memory: 587
# 04/27 01:09:10 - mmengine - INFO - per class results:
# 04/27 01:09:10 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.81 | 94.32 |
# |    road    | 88.07 | 98.84 |
# +------------+-------+-------+
# 04/27 01:09:10 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7500  seg/mIoU: 90.9400  seg/mAcc: 96.5800  cls/acc_cls_top1: 70.2381  data_time: 0.0320  time: 0.0575
# 04/27 01:09:23 - mmengine - INFO - Epoch(train) [1][19050/20]  base_lr: 7.3779e-05 lr: 9.3558e-06  eta: 0:03:39  time: 0.3539  data_time: 0.3257  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0024  scheduler/dev_pred_mean: 0.0193  scheduler/dev_target_mean: 0.0171
# 04/27 01:09:33 - mmengine - INFO - Epoch(train) [1][19100/20]  base_lr: 7.0750e-05 lr: 9.3864e-06  eta: 0:03:27  time: 0.1039  data_time: 0.0759  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0009  scheduler/dev_pred_mean: 0.0127  scheduler/dev_target_mean: 0.0119
# 04/27 01:09:46 - mmengine - INFO - Epoch(train) [1][19150/20]  base_lr: 6.7704e-05 lr: 9.4171e-06  eta: 0:03:16  time: 0.3539  data_time: 0.3259  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0011  scheduler/dev_pred_mean: 0.0212  scheduler/dev_target_mean: 0.0208
# 04/27 01:09:56 - mmengine - INFO - Epoch(train) [1][19200/20]  base_lr: 6.4640e-05 lr: 9.4481e-06  eta: 0:03:04  time: 0.1042  data_time: 0.0759  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0011  scheduler/dev_pred_mean: 0.0235  scheduler/dev_target_mean: 0.0245
# 04/27 01:09:56 - mmengine - INFO - Saving checkpoint at 19200 iterations
# 04/27 01:10:01 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0557  data_time: 0.0313  memory: 587
# 04/27 01:10:03 - mmengine - INFO - per class results:
# 04/27 01:10:03 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.71 | 94.19 |
# |    road    |  87.9 |  98.9 |
# +------------+-------+-------+
# 04/27 01:10:03 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.6800  seg/mIoU: 90.8000  seg/mAcc: 96.5400  cls/acc_cls_top1: 66.6667  data_time: 0.0326  time: 0.0575
# 04/27 01:10:16 - mmengine - INFO - Epoch(train) [1][19250/20]  base_lr: 6.1556e-05 lr: 9.4792e-06  eta: 0:02:53  time: 0.3509  data_time: 0.3230  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0010  scheduler/dev_pred_mean: 0.0170  scheduler/dev_target_mean: 0.0180
# 04/27 01:10:26 - mmengine - INFO - Epoch(train) [1][19300/20]  base_lr: 5.8452e-05 lr: 9.5106e-06  eta: 0:02:41  time: 0.1022  data_time: 0.0742  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0018  scheduler/dev_pred_mean: 0.0193  scheduler/dev_target_mean: 0.0189
# 04/27 01:10:39 - mmengine - INFO - Epoch(train) [1][19350/20]  base_lr: 5.5326e-05 lr: 9.5422e-06  eta: 0:02:30  time: 0.3546  data_time: 0.3262  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0022  scheduler/dev_pred_mean: 0.0146  scheduler/dev_target_mean: 0.0124
# 04/27 01:10:49 - mmengine - INFO - Epoch(train) [1][19400/20]  base_lr: 5.2176e-05 lr: 9.5740e-06  eta: 0:02:18  time: 0.1038  data_time: 0.0755  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0032  scheduler/dev_pred_mean: 0.0146  scheduler/dev_target_mean: 0.0114
# 04/27 01:10:49 - mmengine - INFO - Saving checkpoint at 19400 iterations
# 04/27 01:10:54 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0566  data_time: 0.0322  memory: 587
# 04/27 01:10:56 - mmengine - INFO - per class results:
# 04/27 01:10:56 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.83 | 94.34 |
# |    road    |  88.1 | 98.84 |
# +------------+-------+-------+
# 04/27 01:10:56 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7600  seg/mIoU: 90.9600  seg/mAcc: 96.5900  cls/acc_cls_top1: 65.4762  data_time: 0.0328  time: 0.0576
# 04/27 01:11:09 - mmengine - INFO - Epoch(train) [1][19450/20]  base_lr: 4.8999e-05 lr: 9.6061e-06  eta: 0:02:06  time: 0.3544  data_time: 0.3261  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0008  scheduler/dev_pred_mean: 0.0208  scheduler/dev_target_mean: 0.0216
# 04/27 01:11:19 - mmengine - INFO - Epoch(train) [1][19500/20]  base_lr: 4.5793e-05 lr: 9.6385e-06  eta: 0:01:55  time: 0.1053  data_time: 0.0770  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0014  scheduler/dev_pred_mean: 0.0217  scheduler/dev_target_mean: 0.0205
# 04/27 01:11:32 - mmengine - INFO - Epoch(train) [1][19550/20]  base_lr: 4.2555e-05 lr: 9.6712e-06  eta: 0:01:43  time: 0.3550  data_time: 0.3267  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0033  scheduler/dev_pred_mean: 0.0215  scheduler/dev_target_mean: 0.0248
# 04/27 01:11:42 - mmengine - INFO - Epoch(train) [1][19600/20]  base_lr: 3.9281e-05 lr: 9.7042e-06  eta: 0:01:32  time: 0.1060  data_time: 0.0777  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0011  scheduler/dev_pred_mean: 0.0166  scheduler/dev_target_mean: 0.0177
# 04/27 01:11:42 - mmengine - INFO - Saving checkpoint at 19600 iterations
# 04/27 01:11:48 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:02  time: 0.0580  data_time: 0.0326  memory: 587
# 04/27 01:11:50 - mmengine - INFO - per class results:
# 04/27 01:11:50 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.77 | 94.27 |
# |    road    |  88.0 | 98.85 |
# +------------+-------+-------+
# 04/27 01:11:50 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7200  seg/mIoU: 90.8900  seg/mAcc: 96.5600  cls/acc_cls_top1: 67.8571  data_time: 0.0331  time: 0.0583
# 04/27 01:12:02 - mmengine - INFO - Epoch(train) [1][19650/20]  base_lr: 3.5965e-05 lr: 9.7377e-06  eta: 0:01:20  time: 0.3529  data_time: 0.3247  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0021  scheduler/dev_pred_mean: 0.0195  scheduler/dev_target_mean: 0.0173
# 04/27 01:12:13 - mmengine - INFO - Epoch(train) [1][19700/20]  base_lr: 3.2601e-05 lr: 9.7717e-06  eta: 0:01:09  time: 0.1012  data_time: 0.0730  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0018  scheduler/dev_pred_mean: 0.0159  scheduler/dev_target_mean: 0.0143
# 04/27 01:12:25 - mmengine - INFO - Epoch(train) [1][19750/20]  base_lr: 2.9181e-05 lr: 9.8063e-06  eta: 0:00:57  time: 0.3509  data_time: 0.3227  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0012  scheduler/dev_pred_mean: 0.0125  scheduler/dev_target_mean: 0.0113
# 04/27 01:12:36 - mmengine - INFO - Epoch(train) [1][19800/20]  base_lr: 2.5691e-05 lr: 9.8415e-06  eta: 0:00:46  time: 0.1030  data_time: 0.0748  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0014  scheduler/dev_pred_mean: 0.0190  scheduler/dev_target_mean: 0.0182
# 04/27 01:12:36 - mmengine - INFO - Saving checkpoint at 19800 iterations
# 04/27 01:12:41 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0570  data_time: 0.0321  memory: 587
# 04/27 01:12:43 - mmengine - INFO - per class results:
# 04/27 01:12:43 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.75 | 94.22 |
# |    road    | 87.97 | 98.91 |
# +------------+-------+-------+
# 04/27 01:12:43 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7100  seg/mIoU: 90.8600  seg/mAcc: 96.5600  cls/acc_cls_top1: 76.1905  data_time: 0.0339  time: 0.0587
# 04/27 01:12:56 - mmengine - INFO - Epoch(train) [1][19850/20]  base_lr: 2.2112e-05 lr: 9.8777e-06  eta: 0:00:34  time: 0.3539  data_time: 0.3256  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0017  scheduler/dev_pred_mean: 0.0138  scheduler/dev_target_mean: 0.0121
# 04/27 01:13:06 - mmengine - INFO - Epoch(train) [1][19900/20]  base_lr: 1.8409e-05 lr: 9.9151e-06  eta: 0:00:23  time: 0.1049  data_time: 0.0769  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0005  scheduler/dev_pred_mean: 0.0159  scheduler/dev_target_mean: 0.0155
# 04/27 01:13:18 - mmengine - INFO - Epoch(train) [1][19950/20]  base_lr: 1.4506e-05 lr: 9.9545e-06  eta: 0:00:11  time: 0.3556  data_time: 0.3274  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0015  scheduler/dev_pred_mean: 0.0237  scheduler/dev_target_mean: 0.0235
# 04/27 01:13:29 - mmengine - INFO - Exp name: 03_train_adaptive_scheduler_02pretrain_20260426_234420
# 04/27 01:13:29 - mmengine - INFO - Epoch(train) [1][20000/20]  base_lr: 1.0000e-05 lr: 1.0000e-05  eta: 0:00:00  time: 0.1049  data_time: 0.0764  memory: 1349  loss: 0.0000  scheduler/loss_dev: 0.0000  scheduler/mae_dev: 0.0024  scheduler/dev_pred_mean: 0.0206  scheduler/dev_target_mean: 0.0223
# 04/27 01:13:29 - mmengine - INFO - Saving checkpoint at 20000 iterations
# 04/27 01:13:34 - mmengine - INFO - Epoch(val) [0][50/84]    eta: 0:00:01  time: 0.0560  data_time: 0.0304  memory: 587
# 04/27 01:13:36 - mmengine - INFO - per class results:
# 04/27 01:13:36 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 93.83 | 94.33 |
# |    road    |  88.1 | 98.86 |
# +------------+-------+-------+
# 04/27 01:13:36 - mmengine - INFO - Epoch(val) [0][84/84]    seg/aAcc: 95.7700  seg/mIoU: 90.9700  seg/mAcc: 96.5900  cls/acc_cls_top1: 75.0000  data_time: 0.0329  time: 0.0580
