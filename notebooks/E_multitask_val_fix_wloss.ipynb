# %%
# nombre original archivo: G entrenamiento-Bisenet-2025-automine1d-advtrain guardando bothpth2 DaccestoMask

# %%
## 进入MMSegmentation主目录
import os
os.chdir('/mmsegmentation')

# %% [markdown]
# os.getcwd()

# %%
# !PYTHONPATH=. python tools/train.py zmax_configs/multitask_val_fix_wloss.py
# Out:
# /home/maximilianovelez/miniconda3/envs/open-mmlab-respaldo2/lib/python3.8/site-packages/albumentations/check_version.py:49: UserWarning: Error fetching version info <urlopen error [Errno -3] Temporary failure in name resolution>
#   data = fetch_version_info()
# /bin/sh: 1: x86_64-conda_cos6-linux-gnu-gcc: not found
# 03/25 13:47:39 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1279121275
#     GPU 0,1: NVIDIA A100 80GB PCIe
#     CUDA_HOME: /home/maximilianovelez/miniconda3/envs/open-mmlab-respaldo2
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: n/a
#     PyTorch: 1.13.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     seed: 1279121275
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/25 13:47:42 - mmengine - INFO - Config:
# custom_hooks = []
# custom_imports = dict(
#     allow_failed_imports=False,
#     imports=[
#         'mmseg.structures.dual_task_seg_data_sample',
#         'mmseg.datasets.dual_task_dataset',
#         'mmseg.datasets.transforms.pack_seg_inputs_with_label',
#         'mmseg.datasets.transforms.map_cls_after_flip',
#         'mmseg.models.segmentors.dual_task_segmentor',
#         'mmseg.models.cls_heads.simple_cls_head',
#         'mmseg.models.backbones.bisenetv1',
#         'mmseg.models.backbones.resnet',
#     ])
# data_root = '/home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/automine1d_cls/'
# dataset_type = 'automine1dDual'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=200,
#         max_keep_ckpts=3,
#         rule=[
#             'greater',
#             'greater',
#         ],
#         save_best=[
#             'seg/mIoU',
#             'cls/acc_cls_top1',
#         ],
#         save_last=True,
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(cudnn_benchmark=False)
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         backbone_cfg=dict(
#             depth=50,
#             dilations=(
#                 1,
#                 1,
#                 1,
#                 1,
#             ),
#             in_channels=3,
#             init_cfg=dict(
#                 checkpoint='open-mmlab://resnet50_v1c', type='Pretrained'),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             norm_eval=False,
#             num_stages=4,
#             out_indices=(
#                 0,
#                 1,
#                 2,
#                 3,
#             ),
#             strides=(
#                 1,
#                 2,
#                 2,
#                 2,
#             ),
#             style='pytorch',
#             type='ResNetV1c'),
#         context_channels=(
#             512,
#             1024,
#             2048,
#         ),
#         in_channels=3,
#         init_cfg=None,
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         out_channels=1024,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         spatial_channels=(
#             256,
#             256,
#             256,
#             512,
#         ),
#         type='BiSeNetV1'),
#     cls_head=dict(
#         in_channels=1024,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=3,
#         type='SimpleClsHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         size_divisor=None,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         channels=1024,
#         in_channels=1024,
#         in_index=0,
#         loss_decode=dict(
#             loss_weight=0.5, type='CrossEntropyLoss', use_sigmoid=False),
#         num_classes=2,
#         type='FCNHead'),
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='DualTaskSegmentor')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             backbone=dict(decay_mult=1.0, lr_mult=1.0),
#             cls_head=dict(decay_mult=1.0, lr_mult=3.0),
#             decode_head=dict(decay_mult=1.0, lr_mult=1.5))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(by_epoch=False, eta_min=1e-05, power=0.9, type='PolyLR'),
# ]
# resize_512 = dict(
#     keep_ratio=False, scale=(
#         512,
#         512,
#     ), type='Resize')
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         cls_labels_file='cls_labels_val_aug_fixed.txt',
#         data_prefix=dict(
#             img_path='img_dir/val_aug', seg_map_path='ann_dir/val_aug'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/automine1d_cls/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(keep_ratio=False, scale=(
#                 512,
#                 512,
#             ), type='Resize'),
#             dict(type='PackSegInputsWithLabel'),
#         ],
#         type='automine1dDual'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(iou_metrics=[
#         'mIoU',
#     ], prefix='seg', type='IoUMetric'),
#     dict(prefix='cls', topk=(1, ), type='ClsAccuracy'),
# ]
# train_cfg = dict(max_iters=40000, type='IterBasedTrainLoop', val_interval=200)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         cls_labels_file='cls_labels_train.txt',
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/automine1d_cls/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(keep_ratio=False, scale=(
#                 512,
#                 512,
#             ), type='Resize'),
#             dict(degree=5, prob=0.5, type='RandomRotate'),
#             dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#             dict(
#                 field_name='gt_label',
#                 map_if_flipped=dict({
#                     0: 2,
#                     1: 1,
#                     2: 0
#                 }),
#                 str_map_if_flipped=dict(
#                     derecha='izquierda', izquierda='derecha', recta='recta'),
#                 type='MapClsAfterFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(
#                 clip_limit=3.0,
#                 prob=0.5,
#                 tile_grid_size=(
#                     7,
#                     7,
#                 ),
#                 type='RandomCLAHE'),
#             dict(type='PackSegInputsWithLabel'),
#         ],
#         type='automine1dDual'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(keep_ratio=False, scale=(
#         512,
#         512,
#     ), type='Resize'),
#     dict(degree=5, prob=0.5, type='RandomRotate'),
#     dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#     dict(
#         field_name='gt_label',
#         map_if_flipped=dict({
#             0: 2,
#             1: 1,
#             2: 0
#         }),
#         str_map_if_flipped=dict(
#             derecha='izquierda', izquierda='derecha', recta='recta'),
#         type='MapClsAfterFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         clip_limit=3.0, prob=0.5, tile_grid_size=(
#             7,
#             7,
#         ), type='RandomCLAHE'),
#     dict(type='PackSegInputsWithLabel'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         cls_labels_file='cls_labels_val_aug_fixed.txt',
#         data_prefix=dict(
#             img_path='img_dir/val_aug', seg_map_path='ann_dir/val_aug'),
#         data_root=
#         '/home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/automine1d_cls/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(keep_ratio=False, scale=(
#                 512,
#                 512,
#             ), type='Resize'),
#             dict(type='PackSegInputsWithLabel'),
#         ],
#         type='automine1dDual'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = [
#     dict(iou_metrics=[
#         'mIoU',
#     ], prefix='seg', type='IoUMetric'),
#     dict(prefix='cls', topk=(1, ), type='ClsAccuracy'),
# ]
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(keep_ratio=False, scale=(
#         512,
#         512,
#     ), type='Resize'),
#     dict(type='PackSegInputsWithLabel'),
# ]
# work_dir = './work_dirs/multitask_val_fix_wloss'
#
# /home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 03/25 13:47:48 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# /home/maximilianovelez/00_openmmlab_respaldo/multitask4_trigger/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '
# 03/25 13:47:48 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.0.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.0.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.0.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.0.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.4.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.6.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.6.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.6.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.6.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.stem.7.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.conv3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.bn3.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.0.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.0.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.0.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.0.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.0.downsample.1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.conv3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.1.bn3.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.conv3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer1.2.bn3.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.conv3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.bn3.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.0.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.0.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.0.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.0.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.0.downsample.1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.conv3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.1.bn3.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn1.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.weight:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.weight:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.weight:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.bias:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.bias:weight_decay=0.01
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.bias:lr_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.bn2.bias:decay_mult=1.0
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv3.weight:lr=0.001
# 03/25 13:47:51 - mmengine - INFO - paramwise_options -- backbone.context_path.backbone.layer2.2.conv3.weight:weight_decay=0.01
# ...
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.97 | 99.39 |
# |    road    | 97.81 |  99.1 |
# +------------+-------+-------+
# 03/25 15:39:09 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.3000  seg/mIoU: 98.3900  seg/mAcc: 99.2400  cls/acc_cls_top1: 95.0000  data_time: 0.0303  time: 0.0487
# 03/25 15:39:15 - mmengine - INFO - Epoch(train) [1][38250/21]  base_lr: 6.9228e-05 lr: 6.9228e-05  eta: 0:03:51  time: 0.1234  data_time: 0.0077  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0028  decode.acc_seg: 99.8088  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:39:21 - mmengine - INFO - Epoch(train) [1][38300/21]  base_lr: 6.7703e-05 lr: 6.7703e-05  eta: 0:03:44  time: 0.1203  data_time: 0.0072  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0028  decode.acc_seg: 99.8282  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:39:27 - mmengine - INFO - Epoch(train) [1][38350/21]  base_lr: 6.6173e-05 lr: 6.6173e-05  eta: 0:03:37  time: 0.1218  data_time: 0.0075  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0028  decode.acc_seg: 99.7761  cls.loss_cls: 0.0001  cls.acc_top1: 100.0000
# 03/25 15:39:33 - mmengine - INFO - Epoch(train) [1][38400/21]  base_lr: 6.4639e-05 lr: 6.4639e-05  eta: 0:03:31  time: 0.1214  data_time: 0.0077  memory: 5215  loss: 0.0032  decode.loss_ce: 0.0031  decode.acc_seg: 99.7684  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:39:33 - mmengine - INFO - Saving checkpoint at 38400 iterations
# 03/25 15:39:41 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0505  data_time: 0.0322  memory: 1551
# 03/25 15:39:42 - mmengine - INFO - per class results:
# 03/25 15:39:42 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.95 | 99.33 |
# |    road    | 97.77 | 99.18 |
# +------------+-------+-------+
# 03/25 15:39:42 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2800  seg/mIoU: 98.3600  seg/mAcc: 99.2500  cls/acc_cls_top1: 95.0000  data_time: 0.0288  time: 0.0466
# 03/25 15:39:48 - mmengine - INFO - Epoch(train) [1][38450/21]  base_lr: 6.3099e-05 lr: 6.3099e-05  eta: 0:03:24  time: 0.1219  data_time: 0.0075  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0030  decode.acc_seg: 99.8023  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:39:54 - mmengine - INFO - Epoch(train) [1][38500/21]  base_lr: 6.1555e-05 lr: 6.1555e-05  eta: 0:03:17  time: 0.1240  data_time: 0.0082  memory: 5215  loss: 0.0026  decode.loss_ce: 0.0026  decode.acc_seg: 99.7798  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:00 - mmengine - INFO - Epoch(train) [1][38550/21]  base_lr: 6.0006e-05 lr: 6.0006e-05  eta: 0:03:11  time: 0.1218  data_time: 0.0076  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0028  decode.acc_seg: 99.7958  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:06 - mmengine - INFO - Epoch(train) [1][38600/21]  base_lr: 5.8451e-05 lr: 5.8451e-05  eta: 0:03:04  time: 0.1214  data_time: 0.0073  memory: 5215  loss: 0.0035  decode.loss_ce: 0.0035  decode.acc_seg: 99.7483  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:06 - mmengine - INFO - Saving checkpoint at 38600 iterations
# 03/25 15:40:14 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0477  data_time: 0.0296  memory: 1551
# 03/25 15:40:15 - mmengine - INFO - per class results:
# 03/25 15:40:15 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.97 | 99.36 |
# |    road    | 97.82 | 99.16 |
# +------------+-------+-------+
# 03/25 15:40:15 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.3000  seg/mIoU: 98.3900  seg/mAcc: 99.2600  cls/acc_cls_top1: 95.0000  data_time: 0.0296  time: 0.0477
# 03/25 15:40:21 - mmengine - INFO - Epoch(train) [1][38650/21]  base_lr: 5.6891e-05 lr: 5.6891e-05  eta: 0:02:58  time: 0.1219  data_time: 0.0077  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0028  decode.acc_seg: 99.6527  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:27 - mmengine - INFO - Epoch(train) [1][38700/21]  base_lr: 5.5325e-05 lr: 5.5325e-05  eta: 0:02:51  time: 0.1216  data_time: 0.0075  memory: 5215  loss: 0.0723  decode.loss_ce: 0.0030  decode.acc_seg: 99.7944  cls.loss_cls: 0.0694  cls.acc_top1: 100.0000
# 03/25 15:40:34 - mmengine - INFO - Epoch(train) [1][38750/21]  base_lr: 5.3753e-05 lr: 5.3753e-05  eta: 0:02:44  time: 0.1219  data_time: 0.0078  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0030  decode.acc_seg: 99.8115  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:40 - mmengine - INFO - Epoch(train) [1][38800/21]  base_lr: 5.2175e-05 lr: 5.2175e-05  eta: 0:02:38  time: 0.1212  data_time: 0.0072  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0030  decode.acc_seg: 99.7874  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:40:40 - mmengine - INFO - Saving checkpoint at 38800 iterations
# 03/25 15:40:47 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0487  data_time: 0.0300  memory: 1551
# 03/25 15:40:48 - mmengine - INFO - per class results:
# 03/25 15:40:48 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.88 | 99.37 |
# |    road    | 97.62 | 98.95 |
# +------------+-------+-------+
# 03/25 15:40:48 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2400  seg/mIoU: 98.2500  seg/mAcc: 99.1600  cls/acc_cls_top1: 92.5000  data_time: 0.0309  time: 0.0486
# 03/25 15:40:55 - mmengine - INFO - Epoch(train) [1][38850/21]  base_lr: 5.0590e-05 lr: 5.0590e-05  eta: 0:02:31  time: 0.1231  data_time: 0.0078  memory: 5215  loss: 0.0027  decode.loss_ce: 0.0027  decode.acc_seg: 99.7997  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:41:01 - mmengine - INFO - Epoch(train) [1][38900/21]  base_lr: 4.8998e-05 lr: 4.8998e-05  eta: 0:02:25  time: 0.1211  data_time: 0.0069  memory: 5215  loss: 0.0033  decode.loss_ce: 0.0031  decode.acc_seg: 99.6769  cls.loss_cls: 0.0002  cls.acc_top1: 100.0000
# 03/25 15:41:07 - mmengine - INFO - Epoch(train) [1][38950/21]  base_lr: 4.7399e-05 lr: 4.7399e-05  eta: 0:02:18  time: 0.1219  data_time: 0.0074  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0027  decode.acc_seg: 99.7552  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:41:13 - mmengine - INFO - Exp name: multitask_val_fix_wloss_20260325_134736
# 03/25 15:41:13 - mmengine - INFO - Epoch(train) [1][39000/21]  base_lr: 4.5792e-05 lr: 4.5792e-05  eta: 0:02:11  time: 0.1211  data_time: 0.0072  memory: 5215  loss: 0.0031  decode.loss_ce: 0.0030  decode.acc_seg: 99.7517  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:41:13 - mmengine - INFO - Saving checkpoint at 39000 iterations
# 03/25 15:41:20 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0468  data_time: 0.0284  memory: 1551
# 03/25 15:41:22 - mmengine - INFO - per class results:
# 03/25 15:41:22 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.92 | 99.36 |
# |    road    |  97.7 | 99.03 |
# +------------+-------+-------+
# 03/25 15:41:22 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2600  seg/mIoU: 98.3100  seg/mAcc: 99.2000  cls/acc_cls_top1: 92.5000  data_time: 0.0296  time: 0.0475
# 03/25 15:41:28 - mmengine - INFO - Epoch(train) [1][39050/21]  base_lr: 4.4178e-05 lr: 4.4178e-05  eta: 0:02:05  time: 0.1240  data_time: 0.0079  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0028  decode.acc_seg: 99.7751  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:41:34 - mmengine - INFO - Epoch(train) [1][39100/21]  base_lr: 4.2554e-05 lr: 4.2554e-05  eta: 0:01:58  time: 0.1218  data_time: 0.0075  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0027  decode.acc_seg: 99.7885  cls.loss_cls: 0.0001  cls.acc_top1: 100.0000
# 03/25 15:41:40 - mmengine - INFO - Epoch(train) [1][39150/21]  base_lr: 4.0922e-05 lr: 4.0922e-05  eta: 0:01:52  time: 0.1224  data_time: 0.0076  memory: 5215  loss: 0.0028  decode.loss_ce: 0.0027  decode.acc_seg: 99.7515  cls.loss_cls: 0.0001  cls.acc_top1: 100.0000
# 03/25 15:41:46 - mmengine - INFO - Epoch(train) [1][39200/21]  base_lr: 3.9280e-05 lr: 3.9280e-05  eta: 0:01:45  time: 0.1226  data_time: 0.0075  memory: 5215  loss: 0.0027  decode.loss_ce: 0.0026  decode.acc_seg: 99.7399  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:41:46 - mmengine - INFO - Saving checkpoint at 39200 iterations
# 03/25 15:41:54 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0480  data_time: 0.0299  memory: 1551
# 03/25 15:41:55 - mmengine - INFO - per class results:
# 03/25 15:41:55 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.95 | 99.39 |
# |    road    | 97.76 | 99.04 |
# +------------+-------+-------+
# 03/25 15:41:55 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2800  seg/mIoU: 98.3500  seg/mAcc: 99.2200  cls/acc_cls_top1: 92.5000  data_time: 0.0286  time: 0.0466
# 03/25 15:42:01 - mmengine - INFO - Epoch(train) [1][39250/21]  base_lr: 3.7628e-05 lr: 3.7628e-05  eta: 0:01:38  time: 0.1215  data_time: 0.0077  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0029  decode.acc_seg: 99.7313  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:42:07 - mmengine - INFO - Epoch(train) [1][39300/21]  base_lr: 3.5964e-05 lr: 3.5964e-05  eta: 0:01:32  time: 0.1238  data_time: 0.0079  memory: 5215  loss: 0.0034  decode.loss_ce: 0.0033  decode.acc_seg: 99.6819  cls.loss_cls: 0.0001  cls.acc_top1: 100.0000
# 03/25 15:42:14 - mmengine - INFO - Epoch(train) [1][39350/21]  base_lr: 3.4289e-05 lr: 3.4289e-05  eta: 0:01:25  time: 0.1217  data_time: 0.0073  memory: 5215  loss: 0.0033  decode.loss_ce: 0.0032  decode.acc_seg: 99.7799  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:42:20 - mmengine - INFO - Epoch(train) [1][39400/21]  base_lr: 3.2601e-05 lr: 3.2601e-05  eta: 0:01:19  time: 0.1190  data_time: 0.0067  memory: 5215  loss: 0.0027  decode.loss_ce: 0.0027  decode.acc_seg: 99.7971  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:42:20 - mmengine - INFO - Saving checkpoint at 39400 iterations
# 03/25 15:42:26 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0467  data_time: 0.0282  memory: 1551
# 03/25 15:42:28 - mmengine - INFO - per class results:
# 03/25 15:42:28 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.94 | 99.38 |
# |    road    | 97.74 | 99.06 |
# +------------+-------+-------+
# 03/25 15:42:28 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2700  seg/mIoU: 98.3400  seg/mAcc: 99.2200  cls/acc_cls_top1: 92.5000  data_time: 0.0291  time: 0.0472
# 03/25 15:42:34 - mmengine - INFO - Epoch(train) [1][39450/21]  base_lr: 3.0899e-05 lr: 3.0899e-05  eta: 0:01:12  time: 0.1233  data_time: 0.0076  memory: 5215  loss: 0.0025  decode.loss_ce: 0.0025  decode.acc_seg: 99.8091  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:42:40 - mmengine - INFO - Epoch(train) [1][39500/21]  base_lr: 2.9181e-05 lr: 2.9181e-05  eta: 0:01:05  time: 0.1230  data_time: 0.0075  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0029  decode.acc_seg: 99.8000  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:42:46 - mmengine - INFO - Epoch(train) [1][39550/21]  base_lr: 2.7445e-05 lr: 2.7445e-05  eta: 0:00:59  time: 0.1235  data_time: 0.0080  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0027  decode.acc_seg: 99.7910  cls.loss_cls: 0.0003  cls.acc_top1: 100.0000
# 03/25 15:42:52 - mmengine - INFO - Epoch(train) [1][39600/21]  base_lr: 2.5691e-05 lr: 2.5691e-05  eta: 0:00:52  time: 0.1220  data_time: 0.0073  memory: 5215  loss: 0.0041  decode.loss_ce: 0.0040  decode.acc_seg: 99.7620  cls.loss_cls: 0.0001  cls.acc_top1: 100.0000
# 03/25 15:42:52 - mmengine - INFO - Saving checkpoint at 39600 iterations
# 03/25 15:42:59 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0487  data_time: 0.0305  memory: 1551
# 03/25 15:43:00 - mmengine - INFO - per class results:
# 03/25 15:43:00 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.95 | 99.38 |
# |    road    | 97.76 | 99.07 |
# +------------+-------+-------+
# 03/25 15:43:00 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2800  seg/mIoU: 98.3600  seg/mAcc: 99.2200  cls/acc_cls_top1: 92.5000  data_time: 0.0302  time: 0.0483
# 03/25 15:43:06 - mmengine - INFO - Epoch(train) [1][39650/21]  base_lr: 2.3914e-05 lr: 2.3914e-05  eta: 0:00:46  time: 0.1204  data_time: 0.0070  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0030  decode.acc_seg: 99.7714  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:13 - mmengine - INFO - Epoch(train) [1][39700/21]  base_lr: 2.2112e-05 lr: 2.2112e-05  eta: 0:00:39  time: 0.1218  data_time: 0.0073  memory: 5215  loss: 0.0027  decode.loss_ce: 0.0027  decode.acc_seg: 99.7491  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:19 - mmengine - INFO - Epoch(train) [1][39750/21]  base_lr: 2.0279e-05 lr: 2.0279e-05  eta: 0:00:32  time: 0.1229  data_time: 0.0089  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0029  decode.acc_seg: 99.7944  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:25 - mmengine - INFO - Epoch(train) [1][39800/21]  base_lr: 1.8408e-05 lr: 1.8408e-05  eta: 0:00:26  time: 0.1233  data_time: 0.0077  memory: 5215  loss: 0.0025  decode.loss_ce: 0.0025  decode.acc_seg: 99.7738  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:25 - mmengine - INFO - Saving checkpoint at 39800 iterations
# 03/25 15:43:32 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0483  data_time: 0.0309  memory: 1551
# 03/25 15:43:33 - mmengine - INFO - per class results:
# 03/25 15:43:33 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.96 | 99.36 |
# |    road    |  97.8 | 99.13 |
# +------------+-------+-------+
# 03/25 15:43:33 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2900  seg/mIoU: 98.3800  seg/mAcc: 99.2500  cls/acc_cls_top1: 95.0000  data_time: 0.0288  time: 0.0465
# 03/25 15:43:40 - mmengine - INFO - Epoch(train) [1][39850/21]  base_lr: 1.6490e-05 lr: 1.6490e-05  eta: 0:00:19  time: 0.1215  data_time: 0.0076  memory: 5215  loss: 0.0030  decode.loss_ce: 0.0030  decode.acc_seg: 99.7235  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:46 - mmengine - INFO - Epoch(train) [1][39900/21]  base_lr: 1.4506e-05 lr: 1.4506e-05  eta: 0:00:13  time: 0.1221  data_time: 0.0078  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0029  decode.acc_seg: 99.8085  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:52 - mmengine - INFO - Epoch(train) [1][39950/21]  base_lr: 1.2415e-05 lr: 1.2415e-05  eta: 0:00:06  time: 0.1199  data_time: 0.0072  memory: 5215  loss: 0.0024  decode.loss_ce: 0.0023  decode.acc_seg: 99.8038  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:58 - mmengine - INFO - Exp name: multitask_val_fix_wloss_20260325_134736
# 03/25 15:43:58 - mmengine - INFO - Epoch(train) [1][40000/21]  base_lr: 1.0000e-05 lr: 1.0000e-05  eta: 0:00:00  time: 0.1211  data_time: 0.0074  memory: 5215  loss: 0.0029  decode.loss_ce: 0.0029  decode.acc_seg: 99.8308  cls.loss_cls: 0.0000  cls.acc_top1: 100.0000
# 03/25 15:43:58 - mmengine - INFO - Saving checkpoint at 40000 iterations
# 03/25 15:44:06 - mmengine - INFO - Epoch(val) [0][50/80]    eta: 0:00:01  time: 0.0483  data_time: 0.0308  memory: 1551
# 03/25 15:44:07 - mmengine - INFO - per class results:
# 03/25 15:44:07 - mmengine - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | background | 98.96 | 99.36 |
# |    road    | 97.78 | 99.12 |
# +------------+-------+-------+
# 03/25 15:44:07 - mmengine - INFO - Epoch(val) [0][80/80]    seg/aAcc: 99.2900  seg/mIoU: 98.3700  seg/mAcc: 99.2400  cls/acc_cls_top1: 93.7500  data_time: 0.0304  time: 0.0482
